# %% [markdown]
# # **Prueba 3: conversión de experimentos de actividad neuronal en Igor a Python**

# %%
def conversor(archivo_txt, nombre_csv):

    import csv

    archivo = open(archivo_txt)
    lineas = archivo.readlines()
    archivo.close()

    nombre_archivo_csv = nombre_csv
    with open(nombre_archivo_csv, 'w', newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        escritor_csv.writerow(['-', 'tiempo', 'voltaje'])
        for linea in lineas:
            # Dividir cada línea en base al delimitador (en este caso, una coma)
            datos = linea.strip().split(',')
            escritor_csv.writerow(datos)
    
    return nombre_archivo_csv

def edit_dataframe(nombre_csv):

    import pandas as pd

    spikes = pd.read_csv(nombre_csv) # esta función de pandas lee csv y convierte a dataframe
    work_spikes = spikes.copy()
    df = work_spikes.iloc[1: , [1, 2]] # se selecciona las filas de la 1 en adelante y las columna tiempo y voltaje.

    return df

# %%
conversor('E1.txt', 'E1.csv')
# Out:
# 'E1.csv'

# %%
df1 = edit_dataframe('E1.csv')
# Out:
# C:\Users\carolina\AppData\Local\Temp\ipykernel_5228\3735024354.py:24: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   spikes = pd.read_csv(nombre_csv) # esta función de pandas lee csv y convierte a dataframe

# %%
import matplotlib.pyplot as plt

# %%
# Crear el gráfico
plt.plot(df1["tiempo"], df1["voltaje"], color='b', label= 'voltaje vs tiempo')

# Añadir etiquetas y título
plt.xlabel('Tiempo (ms)')
plt.ylabel('Voltaje (uV)')
plt.title('Actividad neuronal')

# Mostrar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()
